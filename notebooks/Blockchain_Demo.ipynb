# %% [markdown]
# # Blockchain Mining Demo
# Mine a couple of blocks using the proof-of-work implementation.

# %%
from cryptographic_algorithms.blockchain.blockchain import Blockchain
chain = Blockchain(difficulty=3)
chain.add_block({'amount': 10, 'sender': 'Alice', 'recipient': 'Bob'})
chain.add_block({'amount': 5, 'sender': 'Bob', 'recipient': 'Carol'})
[(block.index, block.hash[:10]) for block in chain.chain]

# %%
chain.is_valid()
